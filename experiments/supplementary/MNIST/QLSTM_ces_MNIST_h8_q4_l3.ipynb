# %%
from run_QLSTM_ces_MNIST import run_qlstm_ces_experiment
# Out:
# WARNING:2026-08-25 19:54:20,356:jax._src.xla_bridge:967: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
# n_layers=3
run_qlstm_ces_experiment(n_qubits=4, n_layers=3, N_STEPS=100000)
# Out:
# --- circuit (h8_q4_l3) ---
# 0: ──RX(0.00)─╭||──RX(0.00)─╭●───────╭X──RX(0.00)─╭●───────╭X──RX(0.00)─╭●───────╭X─┤  <Z>
# 1: ──RX(0.00)─├||──RX(0.00)─╰X─╭●────│───RX(0.00)─╰X─╭●────│───RX(0.00)─╰X─╭●────│──┤  <Z>
# 2: ──RX(0.00)─├||──RX(0.00)────╰X─╭●─│───RX(0.00)────╰X─╭●─│───RX(0.00)────╰X─╭●─│──┤  <Z>
# 3: ──RX(0.00)─╰||──RX(0.00)───────╰X─╰●──RX(0.00)───────╰X─╰●──RX(0.00)───────╰X─╰●─┤  <Z>
# (saved to circuits/QLSTMces_q4_l3.png)
# [h8_q4_l3] parameter count: 156  (QRU comparison point: 131)
# No previous state recorded.
# 9, 193: 0.9977040886878967 0.9988452792167664  41.639832973480225 sec
# 19, 193: 1.0015184879302979 1.0038917064666748  70.92081117630005 sec
# 29, 193: 1.0013009309768677 0.9998928308486938  100.68087029457092 sec
# 39, 193: 0.9981217980384827 0.999199390411377  130.8532419204712 sec
# learning rate: 0.0025
# 49, 193: 0.7481584548950195 0.8489803075790405  160.77908992767334 sec
# 59, 193: 0.6650102138519287 0.6939196586608887  190.87871265411377 sec
# ...
