# %%
from run_QLSTM_ces_MNIST import run_qlstm_ces_experiment
# Out:
# WARNING:2026-08-25 20:01:28,788:jax._src.xla_bridge:967: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
# n_layers=3
run_qlstm_ces_experiment(n_qubits=4, n_layers=4, N_STEPS=100000)
# Out:
# --- circuit (h8_q4_l4) ---
# 0: ──RX(0.00)─╭||──RX(0.00)─╭●───────╭X──RX(0.00)─╭●───────╭X──RX(0.00)─╭●───────╭X──RX(0.00)─╭● ···
# 1: ──RX(0.00)─├||──RX(0.00)─╰X─╭●────│───RX(0.00)─╰X─╭●────│───RX(0.00)─╰X─╭●────│───RX(0.00)─╰X ···
# 2: ──RX(0.00)─├||──RX(0.00)────╰X─╭●─│───RX(0.00)────╰X─╭●─│───RX(0.00)────╰X─╭●─│───RX(0.00)─── ···
# 3: ──RX(0.00)─╰||──RX(0.00)───────╰X─╰●──RX(0.00)───────╰X─╰●──RX(0.00)───────╰X─╰●──RX(0.00)─── ···
#
# 0: ··· ───────╭X─┤  <Z>
# 1: ··· ─╭●────│──┤  <Z>
# 2: ··· ─╰X─╭●─│──┤  <Z>
# 3: ··· ────╰X─╰●─┤  <Z>
# (saved to circuits/QLSTMces_q4_l4.png)
# [h8_q4_l4] parameter count: 172  (QRU comparison point: 131)
# No previous state recorded.
# 9, 193: 1.0002466440200806 1.000908613204956  45.48262906074524 sec
# 19, 193: 0.9978323578834534 0.9952229261398315  77.64543843269348 sec
# 29, 193: 0.9997445344924927 0.9999187588691711  109.37102723121643 sec
# 39, 193: 0.9962065815925598 0.996882438659668  141.34192323684692 sec
# ...
