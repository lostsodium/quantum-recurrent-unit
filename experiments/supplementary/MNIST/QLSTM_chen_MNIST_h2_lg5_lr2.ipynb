# %%
from run_QLSTM_chen_MNIST import run_qlstm_chen_experiment

# %%
run_qlstm_chen_experiment(hidden_dim=2, n_layers_gate=5, n_layers_readout=2, N_STEPS=100000)
# Out:
# --- gate circuit (h2_lg5_lr2, gate_qubits=10) ---
# 0: ──H──RY(0.00)──RZ(0.00)─╭||─╭●─────────────────────────╭X──Rot(0.00,0.00,0.00)─╭●──────────── ···
# 1: ──H──RY(0.00)──RZ(0.00)─├||─╰X─╭●──────────────────────│───Rot(0.00,0.00,0.00)─╰X─╭●───────── ···
# 2: ──H──RY(0.00)──RZ(0.00)─├||────╰X─╭●───────────────────│───Rot(0.00,0.00,0.00)────╰X─╭●────── ···
# 3: ──H──RY(0.00)──RZ(0.00)─├||───────╰X─╭●────────────────│───Rot(0.00,0.00,0.00)───────╰X─╭●─── ···
# 4: ──H──RY(0.00)──RZ(0.00)─├||──────────╰X─╭●─────────────│───Rot(0.00,0.00,0.00)──────────╰X─╭● ···
# 5: ──H──RY(0.00)──RZ(0.00)─├||─────────────╰X─╭●──────────│───Rot(0.00,0.00,0.00)─────────────╰X ···
# 6: ──H──RY(0.00)──RZ(0.00)─├||────────────────╰X─╭●───────│───Rot(0.00,0.00,0.00)─────────────── ···
# 7: ──H──RY(0.00)──RZ(0.00)─├||───────────────────╰X─╭●────│───Rot(0.00,0.00,0.00)─────────────── ···
# 8: ──H──RY(0.00)──RZ(0.00)─├||──────────────────────╰X─╭●─│───Rot(0.00,0.00,0.00)─────────────── ···
# ...
