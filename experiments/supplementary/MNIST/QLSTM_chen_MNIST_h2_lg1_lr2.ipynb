# %%
from run_QLSTM_chen_MNIST import run_qlstm_chen_experiment

# %%
run_qlstm_chen_experiment(hidden_dim=2, n_layers_gate=1, n_layers_readout=2, N_STEPS=100000)
# Out:
# --- gate circuit (h2_lg1_lr2, gate_qubits=10) ---
# 0: ──H──RY(0.00)──RZ(0.00)─╭||─╭●─────────────────────────╭X──Rot(0.00,0.00,0.00)─┤  <Z>
# 1: ──H──RY(0.00)──RZ(0.00)─├||─╰X─╭●──────────────────────│───Rot(0.00,0.00,0.00)─┤  <Z>
# 2: ──H──RY(0.00)──RZ(0.00)─├||────╰X─╭●───────────────────│───Rot(0.00,0.00,0.00)─┤
# 3: ──H──RY(0.00)──RZ(0.00)─├||───────╰X─╭●────────────────│───Rot(0.00,0.00,0.00)─┤
# 4: ──H──RY(0.00)──RZ(0.00)─├||──────────╰X─╭●─────────────│───Rot(0.00,0.00,0.00)─┤
# 5: ──H──RY(0.00)──RZ(0.00)─├||─────────────╰X─╭●──────────│───Rot(0.00,0.00,0.00)─┤
# 6: ──H──RY(0.00)──RZ(0.00)─├||────────────────╰X─╭●───────│───Rot(0.00,0.00,0.00)─┤
# 7: ──H──RY(0.00)──RZ(0.00)─├||───────────────────╰X─╭●────│───Rot(0.00,0.00,0.00)─┤
# 8: ──H──RY(0.00)──RZ(0.00)─├||──────────────────────╰X─╭●─│───Rot(0.00,0.00,0.00)─┤
# 9: ──H──RY(0.00)──RZ(0.00)─╰||─────────────────────────╰X─╰●──Rot(0.00,0.00,0.00)─┤
# (saved to circuits/QLSTM_chen_h2_lg1.png)
# ...
