# %%
from run_QGRU_MNIST import run_qgru_experiment
# Out:
# WARNING:2026-08-25 19:20:51,705:jax._src.xla_bridge:967: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
# n_layers=3
run_qgru_experiment(n_qubits=4, n_layers=3)
# Out:
# --- circuit (h8_q4_l3) ---
# 0: ──RX(0.00)─╭||──RX(0.00)─╭●───────╭X──RX(0.00)─╭●───────╭X──RX(0.00)─╭●───────╭X─┤  <Z>
# 1: ──RX(0.00)─├||──RX(0.00)─╰X─╭●────│───RX(0.00)─╰X─╭●────│───RX(0.00)─╰X─╭●────│──┤  <Z>
# 2: ──RX(0.00)─├||──RX(0.00)────╰X─╭●─│───RX(0.00)────╰X─╭●─│───RX(0.00)────╰X─╭●─│──┤  <Z>
# 3: ──RX(0.00)─╰||──RX(0.00)───────╰X─╰●──RX(0.00)───────╰X─╰●──RX(0.00)───────╰X─╰●─┤  <Z>
# (saved to circuits/QGRU_q4_l3.png)
# [h8_q4_l3] parameter count: 144  (QRU comparison point: 131)
# No previous state recorded.
# 9, 193: 0.8485034704208374 0.9350622296333313  31.14118456840515 sec
# 19, 193: 1.0052883625030518 0.8782537579536438  55.08732557296753 sec
# 29, 193: 0.9260838031768799 0.9247995615005493  78.91574311256409 sec
# 39, 193: 0.9903460144996643 0.9924400448799133  105.53258085250854 sec
# learning rate: 0.0025
# 49, 193: 0.5963836312294006 0.7172653675079346  130.14510250091553 sec
# 59, 193: 0.4912012815475464 0.5074188113212585  155.71077609062195 sec
# ...
