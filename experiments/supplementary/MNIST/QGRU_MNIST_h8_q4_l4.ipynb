# %%
from run_QGRU_MNIST import run_qgru_experiment
# Out:
# WARNING:2026-08-25 19:22:30,911:jax._src.xla_bridge:967: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
# n_layers=4
run_qgru_experiment(n_qubits=4, n_layers=4, N_STEPS=100000)
# Out:
# --- circuit (h8_q4_l4) ---
# 0: ──RX(0.00)─╭||──RX(0.00)─╭●───────╭X──RX(0.00)─╭●───────╭X──RX(0.00)─╭●───────╭X──RX(0.00)─╭● ···
# 1: ──RX(0.00)─├||──RX(0.00)─╰X─╭●────│───RX(0.00)─╰X─╭●────│───RX(0.00)─╰X─╭●────│───RX(0.00)─╰X ···
# 2: ──RX(0.00)─├||──RX(0.00)────╰X─╭●─│───RX(0.00)────╰X─╭●─│───RX(0.00)────╰X─╭●─│───RX(0.00)─── ···
# 3: ──RX(0.00)─╰||──RX(0.00)───────╰X─╰●──RX(0.00)───────╰X─╰●──RX(0.00)───────╰X─╰●──RX(0.00)─── ···
#
# 0: ··· ───────╭X─┤  <Z>
# 1: ··· ─╭●────│──┤  <Z>
# 2: ··· ─╰X─╭●─│──┤  <Z>
# 3: ··· ────╰X─╰●─┤  <Z>
# (saved to circuits/QGRU_q4_l4.png)
# [h8_q4_l4] parameter count: 156  (QRU comparison point: 131)
# Loading previous state successfully
# 509, 193: 0.36965617537498474 0.34197455644607544  37.96912145614624 sec
# 519, 193: 0.952831506729126 1.0803501605987549  64.5880720615387 sec
# 529, 193: 0.7255647778511047 0.8001065254211426  91.67032718658447 sec
# learning rate: 0.0003125
# ...
