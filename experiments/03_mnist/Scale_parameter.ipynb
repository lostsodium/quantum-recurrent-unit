# %%
import pickle
import numpy as np

# %%
pkl_names = ['MNIST 3_5 (J8 I8_H8_L4_O8) SEED_2_1-1_current.pkl',
             'MNIST 3_5 (J8 I8_H8_L4_O8) SEED_2_2-1_current.pkl',
             'MNIST 3_5 (J8 I8_H8_L4_O8) SEED_2_3-1_current.pkl',
             'MNIST 3_5 (J8 I8_H8_L4_O8) SEED_2_4-1_current.pkl',
             'MNIST 3_5 (J8 I8_H8_L4_O8) SEED_2_5-1_current.pkl',
             'MNIST 3_5 (J8 I8_H8_L4_O8) SEED_2_6-1_current.pkl',
             'MNIST 3_5 (J8 I8_H8_L4_O8) SEED_2_7-1_current.pkl']

# %%
with open(pkl_name, 'rb') as f:
    (locLossList, locLoss, vlocLoss, lossList, vlossList, loss,
     minLoss, vminLoss, vlocAcc, vmaxAcc, params, loc_params, vloc_params, best_params,
     vbest_params, loc_params_list, vloc_params_list, reset_steps,
     acc_results, i, key2, train_dataset, valid_dataset, test_dataset,
     opt_state, update_lr, learning_rate, all_loss_list, 
     all_vloss_list, dataset_indices, ES_checker, avg_vacc, avg_vloss, avg_v_i) = pickle.load(f)

qc_params = np.array(vbest_params[0])  # parameters for quantum circuit [JAX Array formate]
sca_param = np.array(vbest_params[1][0])  # the parameter for the last step to scale values
# Out:
# WARNING:2026-04-07 20:26:45,327:jax._src.xla_bridge:967: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# /tmp/ipykernel_7440/1278688620.py:7: DeprecationWarning: Pickled array contains an aval with a named_shape attribute. This is deprecated and the code path supporting such avals will be removed. Please re-pickle the array.
#   all_vloss_list, dataset_indices, ES_checker, avg_vacc, avg_vloss, avg_v_i) = pickle.load(f)

# %%
print(pkl_name)
print('sca_param:', sca_param)
# Out:
# MNIST 3_5 (J8 I8_H8_L4_O8) SEED_2_1-1_current.pkl
# sca_param: 102.08885

# %%
for pkl_name in pkl_names:
    with open(pkl_name, 'rb') as f:
        (locLossList, locLoss, vlocLoss, lossList, vlossList, loss,
         minLoss, vminLoss, vlocAcc, vmaxAcc, params, loc_params, vloc_params, best_params,
         vbest_params, loc_params_list, vloc_params_list, reset_steps,
         acc_results, i, key2, train_dataset, valid_dataset, test_dataset,
         opt_state, update_lr, learning_rate, all_loss_list, 
         all_vloss_list, dataset_indices, ES_checker, avg_vacc, avg_vloss, avg_v_i) = pickle.load(f)
    print(pkl_name)
    print('sca_param:', np.array(vbest_params[1][0]))
# Out:
# /tmp/ipykernel_7440/3378483335.py:8: DeprecationWarning: Pickled array contains an aval with a named_shape attribute. This is deprecated and the code path supporting such avals will be removed. Please re-pickle the array.
#   all_vloss_list, dataset_indices, ES_checker, avg_vacc, avg_vloss, avg_v_i) = pickle.load(f)
# MNIST 3_5 (J8 I8_H8_L4_O8) SEED_2_1-1_current.pkl
# sca_param: 102.08885
# MNIST 3_5 (J8 I8_H8_L4_O8) SEED_2_2-1_current.pkl
# sca_param: 102.50507
# MNIST 3_5 (J8 I8_H8_L4_O8) SEED_2_3-1_current.pkl
# sca_param: 108.521126
# MNIST 3_5 (J8 I8_H8_L4_O8) SEED_2_4-1_current.pkl
# sca_param: 101.36923
# MNIST 3_5 (J8 I8_H8_L4_O8) SEED_2_5-1_current.pkl
# sca_param: 106.03426
# MNIST 3_5 (J8 I8_H8_L4_O8) SEED_2_6-1_current.pkl
# sca_param: 100.25433
# MNIST 3_5 (J8 I8_H8_L4_O8) SEED_2_7-1_current.pkl
# sca_param: 96.48195
